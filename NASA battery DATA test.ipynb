# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.io import loadmat, whosmat
import datetime
import pandas as pd
from pandas import DataFrame

# %%
battery = 'B0018'
data_set = loadmat("../data/mat/"+battery+".mat")
print(type(data_set))
# Out:
# <class 'dict'>

# %%
for i in data_set:
    print(i)
# Out:
# __header__
# __version__
# __globals__
# B0018

# %%
val = data_set.get(battery)

# %%
val.ndim
# Out:
# 2

# %%
val.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
val.size
# Out:
# 1

# %%
val.shape
# Out:
# (1, 1)

# %%
len(data_set[battery][0, 0]['cycle'])
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 길이가 사이클의 수
print("len: ",len(data_set[battery][0, 0]['cycle'][0]))
print("size: ",data_set[battery][0, 0]['cycle'][0].size)
# Out:
# len:  319
# size:  319

# %%
# data type: charge, discharge, impedance
print("size:",data_set[battery][0, 0]['cycle'][0, 0]['type'].size)
print(data_set[battery][0, 0]['cycle'][0, 0]['type'])
print("len", len(data_set[battery][0, 0]['cycle'][0, 0]['type']))
print("size:", data_set[battery][0, 0]['cycle'][0, 0]['type'][0].size)
print(data_set[battery][0, 0]['cycle'][0, 0]['type'][0])
print("len:",len(data_set[battery][0, 0]['cycle'][0, 0]['type'][0]))
# Out:
# size: 1
# ['charge']
# len 1
# size: 1
# charge
# len: 6

# %%
print(data_set[battery][0, 0]['cycle'][0, 2]['data'][0][0]['Capacity'][0][0])
# Out:
# 1.8550045207910817

# %%
# 주변 온도

print(data_set[battery][0, 0]['cycle'][0, 0]['ambient_temperature'][0])
print(data_set[battery][0, 0]['cycle'][0, 0]['ambient_temperature'][0][0])
print(data_set[battery][0, 0]['cycle'][0, 0]['ambient_temperature'][0][0].size)
# Out:
# [24]
# 24
# 1

# %%
# 시간
date_time = datetime.datetime(int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][0]), #year
                               int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][1]), #month
                               int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][2]), #day
                               int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][3]), # hour
                               int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][4])) + datetime.timedelta(seconds=int(data_set[battery][0, 0]['cycle'][0, 0]['time'][0][5]))

print(date_time)
# Out:
# 2008-07-07 12:26:45

# %%
# 데이터 추출
data_set[battery][0, 0]['cycle'][0, 0]['data']
# Voltage_measured, Current_measured, Temperature_measured, Current_charge, Voltage_charge, Time
print(len(data_set[battery][0, 0]['cycle'][0, 0]['data'][0][0]))
# 데이터 개수
print(len(data_set[battery][0, 0]['cycle'][0, 0]['data'][0][0]['Voltage_measured'][0]))
# 값
print(data_set[battery][0, 0]['cycle'][0, 0]['data'][0][0]['Voltage_measured'][0][0])
# Out:
# 6
# 2816
# 3.8657128300167622

# %%
print(data_set[battery][0, 0]['cycle'][0, 1]['type'][0])
print(len(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Sense_current'][0]))
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Re'][0])
print("Re", data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Re'][0][0])
print(len(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Battery_impedance'][0]))
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Battery_impedance'][0].size)
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Battery_impedance'][0])
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Battery_impedance'][0][0])
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Battery_impedance'][1][0])



tsf = data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Sense_current'][0][1]
print(tsf)
print(np.real(tsf))
print(np.imag(tsf))
# Out:
# impedance
# 48
# [0.06515815]
# Re 0.06515815158455215
# 1
# 1
# [0.16540953-0.12905434j]
# (0.16540953498211108-0.1290543436750961j)
# (0.18469275241046157-0.10341429510733052j)
# (826.0628662109375-41.28160095214844j)
# 826.0628662109375
# -41.28160095214844

# %%
print(len(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]))
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Rectified_Impedance'][0][0])
print(data_set[battery][0, 0]['cycle'][0, 1]['data'][0][0]['Rectified_Impedance'][0][0].size)
print()
# Out:
# 7
# (0.09531481967353798-0.0016918943033691826j)
# 1
